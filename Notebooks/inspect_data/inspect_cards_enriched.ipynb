# %%
# 1. Load parquet

# %%
# 2. Basic shape and schema

# %%
# 3. Missing values

# %%
# 4. Unique counts

# %%
# 5. Important value distributions

# %%
# 6. Example rows

# %%
# 7. Visualizations

# %%
# 8. Data quality concerns

# %%
# 9. Refactor recommendations
