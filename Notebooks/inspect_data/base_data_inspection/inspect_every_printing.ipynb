# %%
# Check venv matches:
# C:\Users\mitch\source\repos\mtg_ai\.venv\Scripts\python.exe
import sys
print(sys.executable)
# Out:
# C:\Users\mitch\AppData\Local\Programs\Python\Python310\python.exe

# %%
# imports
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# Make pandas usable for wide MTG data
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 120)
pd.set_option("display.width", 0)

# %%
# confirm path to data
PROJECT_ROOT = Path("../../..").resolve()
print(PROJECT_ROOT)
DATA_DIR = PROJECT_ROOT / "data" / "base"
CARDS_EVERY_PATH = DATA_DIR / "every_printing.parquet"
print(CARDS_EVERY_PATH)

# Load parquet to dataframe
cards_every = pd.read_parquet(CARDS_EVERY_PATH)
# Basic shape and schema
print(cards_every.shape)
cards_every.head(5)
# Out:
# C:\Users\mitch\source\repos\mtg_ai
# C:\Users\mitch\source\repos\mtg_ai\data\base\every_printing.parquet
# (522228, 52)
#                                      id                             oracle_id  \
# 0  0000419b-0bba-4488-8f7a-6194544ce91e  b34bb2dc-c1af-4d77-b0b3-a0fb342a5fc6
# 1  0000579f-7b35-4ed3-b44c-db2a538066fe  44623693-51d6-49ad-8cd7-140505caf02f
# 2  00006596-1166-4a79-8443-ca9f82e6db4e  8ae3562f-28b7-4462-96ed-be0cf7052ccc
# 3  00009878-d086-46f0-a964-15734d8368ac  30cd69a8-7893-4075-94ca-04450ff821d3
# 4  0000cd57-91fe-411f-b798-646e965eec37  9f0d82ae-38bf-45d8-8cda-982b6ead1d72
#
#                    name released_at lang  \
# 0                Forest  2024-08-02   en
# 1           Fury Sliver  2006-10-06   en
# 2         Kor Outfitter  2009-10-02   en
# 3  Spirit of the Hearth  2017-08-25   fr
# 4         Siren Lookout  2017-09-29   en
#
#                                                                                                       prices  \
# 0  {'eur': '0.23', 'eur_foil': '0.53', 'tix': '0.03', 'usd': '0.32', 'usd_etched': None, 'usd_foil': '0.41'}
# 1  {'eur': '0.10', 'eur_foil': '1.28', 'tix': '0.03', 'usd': '0.55', 'usd_etched': None, 'usd_foil': '2.94'}
# 2  {'eur': '0.27', 'eur_foil': '2.01', 'tix': '0.03', 'usd': '0.18', 'usd_etched': None, 'usd_foil': '1.73'}
# 3            {'eur': None, 'eur_foil': None, 'tix': None, 'usd': None, 'usd_etched': None, 'usd_foil': None}
# 4  {'eur': '0.08', 'eur_foil': '0.20', 'tix': '0.03', 'usd': '0.14', 'usd_etched': None, 'usd_foil': '0.35'}
#
#    highres_image  image_status  reserved   foil  nonfoil         finishes  \
# 0           True  highres_scan     False   True     True  [nonfoil, foil]
# 1           True  highres_scan     False   True     True  [nonfoil, foil]
# 2           True  highres_scan     False   True     True  [nonfoil, foil]
# 3          False        lowres     False  False     True        [nonfoil]
# 4           True  highres_scan     False   True     True  [nonfoil, foil]
#
#    oversized  promo  reprint  variation                                set_id  \
# 0      False  False     True      False  a2f58272-bba6-439d-871e-7a46686ac018
# 1      False  False    False      False  c1d109bc-ffd8-428f-8d7d-3f8d7e648046
# 2      False  False    False      False  eb16a2bd-a218-4e4e-8339-4aa1afc0c8d2
# 3      False  False     True      False  5caec427-0c78-4c37-b4ec-30f7e0ba9abf
# 4      False  False    False      False  fe0dad85-54bc-4151-9200-d68da84dd0f2
#
#    set        set_name   set_type collector_number  digital  \
# 0  blb     Bloomburrow  expansion              280    False
# 1  tsp     Time Spiral  expansion              157    False
# 2  zen        Zendikar  expansion               21    False
# 3  c17  Commander 2017  commander               73    False
# 4  xln          Ixalan  expansion               78    False
#
#                            card_back_id              artist  \
# 0  0aeebaf5-8c7d-4636-9e82-8c27447861f7  David Robert Hovey
# 1  0aeebaf5-8c7d-4636-9e82-8c27447861f7       Paolo Parente
# 2  0aeebaf5-8c7d-4636-9e82-8c27447861f7       Kieran Yanner
# 3  0aeebaf5-8c7d-4636-9e82-8c27447861f7          Jason Chan
# 4  0aeebaf5-8c7d-4636-9e82-8c27447861f7        Chris Rallis
#
#                                artist_ids  \
# 0  [22ab27e3-6476-48f1-a9f7-9a9e86339030]
# 1  [d48dd097-720d-476a-8722-6a02854ae28b]
# 2  [aa7e89ed-d294-4633-9057-ce04dacfcfa4]
# 3  [8062d5a9-51b6-4822-933f-fa9e9dba8416]
# 4  [a8e7b854-b15a-421a-b66d-6e68187ae285]
#
#                         illustration_id border_color frame  full_art  \
# 0  fb2b1ca2-7440-48c2-81c8-84da0a45a626        black  2015      True
# 1  2fcca987-364c-4738-a75b-099d8a26d614        black  2003     False
# 2  de0310d1-e97f-46e0-bc16-c980c2adedee        black  2003     False
# 3  e8a09f86-98f6-46df-bf53-46a9f4117f36        black  2015     False
# 4  e0a40a54-9216-4c86-b9e3-daed04abc310        black  2015     False
#
#    textless  layout  booster  story_spotlight  \
# 0     False  normal     True            False
# 1     False  normal     True            False
# 2     False  normal     True            False
# 3     False  normal    False            False
# 4     False  normal     True            False
#
#                                                                                                       prints_search_uri  \
# 0  https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab34bb2dc-c1af-4d77-b0b3-a0fb342a5fc6&unique=prints
# 1  https://api.scryfall.com/cards/search?order=released&q=oracleid%3A44623693-51d6-49ad-8cd7-140505caf02f&unique=prints
# 2  https://api.scryfall.com/cards/search?order=released&q=oracleid%3A8ae3562f-28b7-4462-96ed-be0cf7052ccc&unique=prints
# 3  https://api.scryfall.com/cards/search?order=released&q=oracleid%3A30cd69a8-7893-4075-94ca-04450ff821d3&unique=prints
# 4  https://api.scryfall.com/cards/search?order=released&q=oracleid%3A9f0d82ae-38bf-45d8-8cda-982b6ead1d72&unique=prints
#
#    tcgplayer_etched_id  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#                                                                                                                flavor_text  \
# 0                                                                                                                     None
# 1  "A rift opened, and our arrows were abruptly stilled. To move was to push the world. But the sliver's claw still twi...
# 2                                                  "We take only what we need to survive. Believe me, you will need this."
# 3                              Les voleurs savent qu'un grognement dans la nuit signifie, « Allez cambrioler autre part. »
# 4                                                                                                                     None
#
#                                                                                                              purchase_uris  \
# 0  {'cardhoarder': 'https://www.cardhoarder.com/cards/129825?affiliate_id=scryfall&ref=card-profile&utm_campaign=affili...
# 1  {'cardhoarder': 'https://www.cardhoarder.com/cards/25527?affiliate_id=scryfall&ref=card-profile&utm_campaign=affilia...
# 2  {'cardhoarder': 'https://www.cardhoarder.com/cards/34586?affiliate_id=scryfall&ref=card-profile&utm_campaign=affilia...
# 3  {'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Spirit+of+the+Hearth&ref=c...
# 4  {'cardhoarder': 'https://www.cardhoarder.com/cards/65170?affiliate_id=scryfall&ref=card-profile&utm_campaign=affilia...
#
#       printed_name          printed_type_line  \
# 0             None                       None
# 1             None                       None
# 2             None                       None
# 3  Esprit du foyer  Créature : chat et esprit
# 4             None                       None
#
#                                                                                                               printed_text  \
# 0                                                                                                                     None
# 1                                                                                                                     None
# 2                                                                                                                     None
# 3  Vol\nVous avez la défense talismanique. (Vous ne pouvez pas être la cible de sorts ou de capacités que vos adversair...
# 4                                                                                                                     None
#
#   security_stamp promo_types watermark frame_effects preview variation_of  \
# 0           None        None      None          None    None         None
# 1           None        None      None          None    None         None
# 2           None        None      None          None    None         None
# 3           oval        None      None          None    None         None
# 4           None        None      None          None    None         None
#
#   content_warning flavor_name         finishes_key  \
# 0            None        None  ["nonfoil", "foil"]
# 1            None        None  ["nonfoil", "foil"]
# 2            None        None  ["nonfoil", "foil"]
# 3            None        None          ["nonfoil"]
# 4            None        None  ["nonfoil", "foil"]
#
#                              artist_ids_key promo_types_key frame_effects_key
# 0  ["22ab27e3-6476-48f1-a9f7-9a9e86339030"]            None              None
# 1  ["d48dd097-720d-476a-8722-6a02854ae28b"]            None              None
# 2  ["aa7e89ed-d294-4633-9057-ce04dacfcfa4"]            None              None
# 3  ["8062d5a9-51b6-4822-933f-fa9e9dba8416"]            None              None
# 4  ["a8e7b854-b15a-421a-b66d-6e68187ae285"]            None              None

# %%
cards_every.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522228 entries, 0 to 522227
# Data columns (total 52 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   522228 non-null  object
#  1   oracle_id            522147 non-null  object
#  2   name                 522228 non-null  object
#  3   released_at          522228 non-null  object
#  4   lang                 522228 non-null  object
#  5   prices               522228 non-null  object
#  6   highres_image        522228 non-null  bool
#  7   image_status         522228 non-null  object
#  8   reserved             522228 non-null  bool
#  9   foil                 522228 non-null  bool
#  10  nonfoil              522228 non-null  bool
#  11  finishes             522228 non-null  object
#  12  oversized            522228 non-null  bool
#  13  promo                522228 non-null  bool
#  14  reprint              522228 non-null  bool
#  15  variation            522228 non-null  bool
#  16  set_id               522228 non-null  object
#  17  set                  522228 non-null  object
#  18  set_name             522228 non-null  object
#  19  set_type             522228 non-null  object
#  20  collector_number     522228 non-null  object
#  21  digital              522228 non-null  bool
#  22  card_back_id         516765 non-null  object
#  23  artist               522228 non-null  object
#  24  artist_ids           521652 non-null  object
#  25  illustration_id      516265 non-null  object
#  26  border_color         522228 non-null  object
#  27  frame                522228 non-null  object
#  28  full_art             522228 non-null  bool
#  29  textless             522228 non-null  bool
#  30  layout               522228 non-null  object
#  31  booster              522228 non-null  bool
#  32  story_spotlight      522228 non-null  bool
#  33  prints_search_uri    522228 non-null  object
#  34  tcgplayer_etched_id  1225 non-null    float64
#  35  flavor_text          265780 non-null  object
#  36  purchase_uris        518500 non-null  object
#  37  printed_name         396843 non-null  object
#  38  printed_type_line    345024 non-null  object
#  39  printed_text         346400 non-null  object
#  40  security_stamp       159542 non-null  object
#  41  promo_types          85829 non-null   object
#  42  watermark            36365 non-null   object
#  43  frame_effects        68560 non-null   object
#  44  preview              16485 non-null   object
#  45  variation_of         120 non-null     object
#  46  content_warning      91 non-null      object
#  47  flavor_name          591 non-null     object
#  48  finishes_key         522228 non-null  object
#  49  artist_ids_key       521652 non-null  object
#  50  promo_types_key      85829 non-null   object
#  51  frame_effects_key    68560 non-null   object
# dtypes: bool(13), float64(1), object(38)
# memory usage: 161.9+ MB

# %%
# Identity checks
print(f"Rows: {len(cards_every):,}")
print(f"Unique id: {cards_every['id'].nunique():,}")
print(f"Unique oracle_id: {cards_every['oracle_id'].nunique():,}")

print(f"Duplicate id rows: {cards_every['id'].duplicated().sum():,}")
print(f"Duplicate oracle_id rows: {cards_every['oracle_id'].duplicated().sum():,}")
# Out:
# Rows: 522,228
# Unique id: 522,228
# Unique oracle_id: 33,480
# Duplicate id rows: 0
# Duplicate oracle_id rows: 488,747

# %%
# Missing values overview
missing = cards_every.isnull().sum().sort_values(ascending=False)

missing[missing > 0]
# Out:
# content_warning        522137
# variation_of           522108
# flavor_name            521637
# tcgplayer_etched_id    521003
# preview                505743
# watermark              485863
# frame_effects_key      453668
# frame_effects          453668
# promo_types_key        436399
# promo_types            436399
# security_stamp         362686
# flavor_text            256448
# printed_type_line      177204
# printed_text           175828
# printed_name           125385
# illustration_id          5963
# card_back_id             5463
# purchase_uris            3728
# artist_ids_key            576
# artist_ids                576
# oracle_id                  81
# dtype: int64

# %%
# Layout distribution
layout_counts = cards_every["layout"].value_counts()

display(layout_counts)

fig, (ax_top, ax_bottom) = plt.subplots(
    2,
    1,
    sharex=True,
    figsize=(12, 7),
    gridspec_kw={"height_ratios": [1, 3]}
)

layout_counts.plot(kind="bar", ax=ax_top)
layout_counts.plot(kind="bar", ax=ax_bottom)

non_normal_counts = layout_counts.drop(labels=["normal"], errors="ignore")
max_non_normal = non_normal_counts.max()

ax_top.set_ylim(layout_counts.max() * 0.90, layout_counts.max() * 1.05)
ax_bottom.set_ylim(0, max_non_normal * 1.15)

ax_top.spines["bottom"].set_visible(False)
ax_bottom.spines["top"].set_visible(False)

ax_bottom.tick_params(axis="x", rotation=45)

ax_top.set_title("Printing Layout Distribution")
ax_bottom.set_ylabel("Count")

plt.tight_layout()
plt.show()
# Out:
# normal             509927
# transform            4252
# saga                 1621
# adventure            1578
# split                1493
# modal_dfc            1130
# mutate                570
# prepare               341
# leveler               311
# class                 306
# meld                  231
# prototype             208
# case                  114
# reversible_card        81
# flip                   48
# augment                17
# Name: layout, dtype: int64

# %%
# Set type distribution
set_type_counts = cards_every["set_type"].value_counts()

display(set_type_counts)

set_type_counts.plot(kind="bar", figsize=(12, 5))
plt.title("Set Type Distribution")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# expansion           252362
# commander            79411
# core                 62835
# draft_innovation     46192
# masters              35950
# promo                11919
# box                   8936
# masterpiece           5557
# starter               4772
# duel_deck             4054
# memorabilia           2769
# eternal               2121
# funny                 2110
# planechase            1261
# alchemy                969
# treasure_chest         431
# archenemy              256
# from_the_vault         156
# premium_deck           105
# arsenal                 34
# spellbook               24
# token                    4
# Name: set_type, dtype: int64
